# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# blis                               0.7.4
# bokeh                              2.2.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# bs4                                0.0.1
# catalogue                          1.0.0
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.7
# conda                              4.9.2
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.1.1
# cycler                             0.10.0
# cymem                              2.0.5
# Cython                             0.29.21
# cytoolz                            0.11.0
# dartsclone                         0.9.0
# dask                               2.30.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# distributed                        2.30.1
# docutils                           0.16
# emoji                              1.5.0
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# fsspec                             0.8.3
# future                             0.18.2
# gevent                             20.9.0
# ginza                              4.0.6
# glob2                              0.7
# greenlet                           0.4.17
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 2.0.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.19.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# ja-ginza                           4.0.0
# japanize-matplotlib                1.1.3
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# joblib                             0.17.0
# json5                              0.9.5
# jsonpickle                         2.0.0
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.6.3
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# keyring                            21.4.0
# kiwisolver                         1.3.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# llvmlite                           0.34.0
# locket                             0.2.0
# lxml                               4.6.1
# MarkupSafe                         1.1.1
# matplotlib                         3.3.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.2
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# murmurhash                         1.0.5
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.19.2
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.5
# packaging                          20.4
# pandas                             1.1.3
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.1.0
# path                               15.0.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# pathy                              0.6.0
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.0.1
# pip                                20.2.4
# pkginfo                            1.6.1
# plac                               1.1.3
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.5
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.8
# psutil                             5.7.2
# py                                 1.9.0
# pycodestyle                        2.6.0
# pycodestyle-magic                  0.5
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydantic                           1.8.2
# pydocstyle                         5.1.1
# pyflakes                           2.2.0
# Pygments                           2.7.2
# pylint                             2.6.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# pytz                               2020.1
# pyvis                              0.1.9
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.2
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# rope                               0.18.0
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# scikit-image                       0.17.2
# scikit-learn                       0.23.2
# scipy                              1.5.2
# seaborn                            0.11.0
# Send2Trash                         1.5.0
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# sklearn                            0.0
# smart-open                         5.2.1
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.1.0
# soupsieve                          2.0.1
# spacy                              2.3.7
# spacy-legacy                       3.0.8
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# srsly                              1.0.5
# statsmodels                        0.12.0
# SudachiDict-core                   20210802
# SudachiPy                          0.5.3
# sympy                              1.6.2
# tables                             3.6.1
# tblib                              1.7.0
# terminado                          0.9.1
# testpath                           0.4.4
# thinc                              7.4.5
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# toml                               0.10.1
# toolz                              0.11.1
# tornado                            6.0.4
# tqdm                               4.50.2
# traitlets                          5.0.5
# typer                              0.4.0
# typing-extensions                  3.7.4.3
# ujson                              4.0.1
# unicodecsv                         0.14.1
# urllib3                            1.25.11
# wasabi                             0.8.2
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.8.1
# wrapt                              1.11.2
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2

# %%
# !pip install ginza==4.0.6 ja-ginza==4.0.0
# !pip install sklearn pandas
# !pip install flake8 pycodestyle_magic
# Out:
# Requirement already satisfied: ginza==4.0.6 in c:\users\ay-is\appdata\roaming\python\python38\site-packages (4.0.6)
# Requirement already satisfied: ja-ginza==4.0.0 in c:\users\ay-is\appdata\roaming\python\python38\site-packages (4.0.0)
# Requirement already satisfied: SudachiPy>=0.4.9; python_version >= "3.5" in c:\users\ay-is\anaconda3\lib\site-packages (from ginza==4.0.6) (0.5.3)
# Requirement already satisfied: SudachiDict-core>=20200330; python_version >= "3.5" in c:\users\ay-is\anaconda3\lib\site-packages (from ginza==4.0.6) (20210802)
# Requirement already satisfied: spacy<3.0.0,>=2.3.2 in c:\users\ay-is\anaconda3\lib\site-packages (from ginza==4.0.6) (2.3.7)
# Requirement already satisfied: sortedcontainers~=2.1.0 in c:\users\ay-is\anaconda3\lib\site-packages (from SudachiPy>=0.4.9; python_version >= "3.5"->ginza==4.0.6) (2.1.0)
# Requirement already satisfied: dartsclone~=0.9.0 in c:\users\ay-is\anaconda3\lib\site-packages (from SudachiPy>=0.4.9; python_version >= "3.5"->ginza==4.0.6) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (0.8.2)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (7.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (3.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (2.24.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.0.5)
# Requirement already satisfied: setuptools in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.19.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (0.7.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (4.50.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.1.3)
# Requirement already satisfied: Cython in c:\users\ay-is\anaconda3\lib\site-packages (from dartsclone~=0.9.0->SudachiPy>=0.4.9; python_version >= "3.5"->ginza==4.0.6) (0.29.21)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.6) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.6) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.6) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.0.0,>=2.3.2->ginza==4.0.6) (1.25.11)
# Requirement already satisfied: spacy in c:\users\ay-is\anaconda3\lib\site-packages (2.3.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Requirement already satisfied: setuptools in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (7.4.5)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (1.19.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\ay-is\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ay-is\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: sklearn in c:\users\ay-is\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: pandas in c:\users\ay-is\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: scikit-learn in c:\users\ay-is\anaconda3\lib\site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ay-is\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ay-is\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\ay-is\anaconda3\lib\site-packages (from pandas) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\ay-is\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ay-is\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\ay-is\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\ay-is\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Requirement already satisfied: flake8 in c:\users\ay-is\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: pycodestyle_magic in c:\users\ay-is\anaconda3\lib\site-packages (0.5)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\ay-is\anaconda3\lib\site-packages (from flake8) (0.6.1)
# Requirement already satisfied: pyflakes<2.3.0,>=2.2.0 in c:\users\ay-is\anaconda3\lib\site-packages (from flake8) (2.2.0)
# Requirement already satisfied: pycodestyle<2.7.0,>=2.6.0a1 in c:\users\ay-is\anaconda3\lib\site-packages (from flake8) (2.6.0)

# %%
# read_review1.py

import pandas as pd

# 口コミデータの読み込み
df = pd.read_csv('text/miyajima_sample.csv', encoding='utf-8',
                 parse_dates=['旅行の時期'])
display(df)
# Out:
#     居住地   年代  性別      旅行の時期      同行者     評価               タイトル  \
# 0    広島  50代  男性 2021-10-01       家族  とても良い           まあきてみんさい
# 1    広島  30代  女性 2021-10-01       友達  とても良い  魅力満載のワンダーアイランドです！
# 2    広島  30代  女性 2021-10-01       家族  とても良い              宮島グルメ
# 3    広島  10代  男性 2021-10-01  カップル・夫婦  とても良い              牡蠣の聖地
# 4    広島  20代  女性 2021-10-01       友達  とても良い               宮島観光
# ..   ..  ...  ..        ...      ...    ...                ...
# 171  愛媛  50代  男性 2008-08-01     ビジネス  とても良い                街並み
# 172  広島  50代  男性 2007-09-01       家族  とても良い                宮島へ
# 173  広島  10代  男性 2003-12-01       家族     普通          可もなく不可もなく
# 174  広島  10代  男性 2001-12-01  カップル・夫婦  とても良い     宮島はとてもいい場所！！！！
# 175  広島  20代  男性 2000-09-01       友達  とても良い            8年ぶりの宮島
#
#                                                    口コミ
# 0                   自然の景色　雅な社殿　ときめきいっぱいの商店街　海のにおい　いいよお
# 1    パワースポットでもある厳島神社を参拝したり、牡蠣やもみじ饅頭、穴子飯をはじめとしたグルメは有...
# 2    宮島のグルメを楽しむために母と訪問しました。昼食は、牡蠣屋という牡蠣料理専門店で牡蠣屋定食を...
# 3                                       牡蠣好きには堪らないです！！
# 4    試験の帰りに宮島へ寄りました。フェリーから降りてすぐに昼食をとろうとなり、商店街を歩きました...
# ..                                                 ...
# 171                               観光気分を味わえる。街並みが綺麗である。
# 172  広島で働くことが決まったので、家族で広島を見学に来ました。せっかくなので、観光地の宮島へ行き...
# 173                 幼い頃に行くのは楽しいが大学生、社会人になるにつれ行く意欲が湧かない
# 174                                          シカが可愛かった❤
# 175  宮島は食べ歩きのイメージが強い観光地だったのですが、イメージ通り食べ歩きができる飲食店ばかり...
#
# [176 rows x 8 columns]

# %%
# read_review2.py

# 口コミの件数の算出　
count = len(df)
print("口コミの件数", count)

# 口コミの平均文字数の算出
word_count = 0
for review in df["口コミ"]:
    word_count += len(review)

ave = word_count / count
print("口コミの平均文字数", round(ave, 1))
# Out:
# 口コミの件数 176
# 口コミの平均文字数 175.1
